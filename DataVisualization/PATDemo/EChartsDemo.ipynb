# %%
from pyecharts import Geo

data = [
    ("海门", 9),("鄂尔多斯", 12),("招远", 12),("舟山", 12),("齐齐哈尔", 14),("盐城", 15),
    ("赤峰", 16),("青岛", 18),("乳山", 18),("金昌", 19),("泉州", 21),("莱西", 21),
    ("日照", 21),("胶南", 22),("南通", 23),("拉萨", 24),("云浮", 24),("梅州", 25),
    ("文登", 25),("上海", 25),("攀枝花", 25),("威海", 25),("承德", 25),("厦门", 26),
    ("汕尾", 26),("潮州", 26),("丹东", 27),("太仓", 27),("曲靖", 27),("烟台", 28),
    ("福州", 29),("瓦房店", 30),("即墨", 30),("抚顺", 31),("玉溪", 31),("张家口", 31),
    ("阳泉", 31),("莱州", 32),("湖州", 32),("汕头", 32),("昆山", 33),("宁波", 33),
    ("湛江", 33),("揭阳", 34),("荣成", 34),("连云港", 35),("葫芦岛", 35),("常熟", 36),
    ("东莞", 36),("河源", 36),("淮安", 36),("泰州", 36),("南宁", 37),("营口", 37),
    ("惠州", 37),("江阴", 37),("蓬莱", 37),("韶关", 38),("嘉峪关", 38),("广州", 38),
    ("延安", 38),("太原", 39),("清远", 39),("中山", 39),("昆明", 39),("寿光", 40),
    ("盘锦", 40),("长治", 41),("深圳", 41),("珠海", 42),("宿迁", 43),("咸阳", 43),
    ("铜川", 44),("平度", 44),("佛山", 44),("海口", 44),("江门", 45),("章丘", 45),
    ("肇庆", 46),("大连", 47),("临汾", 47),("吴江", 47),("石嘴山", 49),("沈阳", 50),
    ("苏州", 50),("茂名", 50),("嘉兴", 51),("长春", 51),("胶州", 52),("银川", 52),
    ("张家港", 52),("三门峡", 53),("锦州", 54),("南昌", 54),("柳州", 54),("三亚", 54),
    ("自贡", 56),("吉林", 56),("阳江", 57),("泸州", 57),("西宁", 57),("宜宾", 58),
    ("呼和浩特", 58),("成都", 58),("大同", 58),("镇江", 59),("桂林", 59),("张家界", 59),
    ("宜兴", 59),("北海", 60),("西安", 61),("金坛", 62),("东营", 62),("牡丹江", 63),
    ("遵义", 63),("绍兴", 63),("扬州", 64),("常州", 64),("潍坊", 65),("重庆", 66),
    ("台州", 67),("南京", 67),("滨州", 70),("贵阳", 71),("无锡", 71),("本溪", 71),
    ("克拉玛依", 72),("渭南", 72),("马鞍山", 72),("宝鸡", 72),("焦作", 75),("句容", 75),
    ("北京", 79),("徐州", 79),("衡水", 80),("包头", 80),("绵阳", 80),("乌鲁木齐", 84),
    ("枣庄", 84),("杭州", 84),("淄博", 85),("鞍山", 86),("溧阳", 86),("库尔勒", 86),
    ("安阳", 90),("开封", 90),("济南", 92),("德阳", 93),("温州", 95),("九江", 96),
    ("邯郸", 98),("临安", 99),("兰州", 99),("沧州", 100),("临沂", 103),("南充", 104),
    ("天津", 105),("富阳", 106),("泰安", 112),("诸暨", 112),("郑州", 113),("哈尔滨", 114),
    ("聊城", 116),("芜湖", 117),("唐山", 119),("平顶山", 119),("邢台", 119),("德州", 120),
    ("济宁", 120),("荆州", 127),("宜昌", 130),("义乌", 132),("丽水", 133),("洛阳", 134),
    ("秦皇岛", 136),("株洲", 143),("石家庄", 147),("莱芜", 148),("常德", 152),("保定", 153),
    ("湘潭", 154),("金华", 157),("岳阳", 169),("长沙", 175),("衢州", 177),("廊坊", 193),
    ("菏泽", 194),("合肥", 229),("武汉", 273),("大庆", 279)]

geo = Geo("全国主要城市空气质量", "data from pm2.5", title_color="#fff",
          title_pos="center", width=1200,
          height=600, background_color='#404a59')
attr, value = geo.cast(data)
geo.add("", attr, value, visual_range=[0, 200], visual_text_color="#fff",
        symbol_size=15, is_visualmap=True)
geo.render()
geo
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="b5b16c75605942149ba03f478375df72" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_b5b16c75605942149ba03f478375df72 = echarts.init(document.getElementById('b5b16c75605942149ba03f478375df72'), null, {renderer: 'canvas'});
# var option_b5b16c75605942149ba03f478375df72 = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u4e3b\u8981\u57ce\u5e02\u7a7a\u6c14\u8d28\u91cf",
#             "subtext": "data from pm2.5",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
# ...

# %%
#load data
import json
f = open('data\\2.txt', "r+", encoding='UTF-8')

data = json.load(f)
print(data)
# Out:
# {'三亚市 ': 904, '三明市 ': 2271, '上海市 ': 3385.33, '东莞市 ': 1277, '临沂市 ': 1874, '乐山市 ': 1723, '佛山市 ': 1894, '保定市 ': 1262.75, '兰州市 ': 1818.5, '兴义市 ': 296, '包头市 ': 2096, '北京市 ': 3684.47, '南京市 ': 4641.75, '南充市 ': 372, '南昌市 ': 2605.5, '厦门市 ': 2927, '台州市 ': 4775, '合肥市 ': 2398, '吉首市 ': 3419, '吕梁市 ': 368, '周口市 ': 1155, '呼和浩特市 ': 2017.25, '咸阳市 ': 2303, '哈尔滨市 ': 1485.33, '大连市 ': 2675.8, '天津市 ': 2248.33, '太原市 ': 1537, '威海市 ': 3973, '宁波市 ': 3901.75, '安阳市 ': 2437, '宝鸡市 ': 625, '常州市 ': 3646, '平顶山市 ': 2553, '广州市 ': 1590.25, '廊坊市 ': 1127, '开封市 ': 3628, '徐州市 ': 2859, '怀化市 ': 2977, '惠州市 ': 2690, '成都市 ': 3411.5, '新乡市 ': 529, '新余市 ': 1499, '无锡市 ': 1398, '日照市 ': 558, '昆明市 ': 1463, '晋中市 ': 1247.33, '杭州市 ': 4080.45, '柳州市 ': 487, '株洲市 ': 2413, '桂林市 ': 1335, '武汉市 ': 1962.17, '汕头市 ': 2925, '汶川县 ': 483, '沈阳市 ': 2789, '泉州市 ': 1598, '济南市 ': 1593, '海口市 ': 2010.8, '淄博市 ': 5370, '深圳市 ': 3749.67, '温州市 ': 3327, '湖州市 ': 2883, '湘潭市 ': 3603, '漳州市 ': 3878, '焦作市 ': 3569, '石家庄市 ': 3821, '福州市 ': 2182.75, '秦皇岛市 ': 4533.5, '绍兴市 ': 
# ...

# %%
dataMaps=[]
for i in data:
    dataMaps.append( (i[:-1], data[i]) )

# %%
geo = Geo("全国主要城市PAT平均分数", "data for PAT", title_color="#fff",
          title_pos="center", width=1200,
          height=600, background_color='#404a59')
attr, value = geo.cast(dataMaps)
geo.add("", attr, value, visual_range=[0, 4000], visual_text_color="#fff",
        symbol_size=15, is_visualmap=True)
geo.render()
geo
# Out:
# 襄阳市 coordinates is not found
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="cbd80c59d5e347dbadab7a7a1a1821bd" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_cbd80c59d5e347dbadab7a7a1a1821bd = echarts.init(document.getElementById('cbd80c59d5e347dbadab7a7a1a1821bd'), null, {renderer: 'canvas'});
# var option_cbd80c59d5e347dbadab7a7a1a1821bd = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u4e3b\u8981\u57ce\u5e02PAT\u5e73\u5747\u5206\u6570",
#             "subtext": "data for PAT",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
# ...
