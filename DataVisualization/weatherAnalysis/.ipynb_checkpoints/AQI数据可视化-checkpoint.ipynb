# %%
import datetime
import random
from pyecharts import Map
from pyecharts import HeatMap
import pandas as pd
begin = datetime.date(2017, 1, 1)
end = datetime.date(2017, 12, 31)
data = [[str(begin + datetime.timedelta(days=i)),
        random.randint(1000, 25000)] for i in range((end - begin).days + 1)]
heatmap = HeatMap("日历热力图示例", "某人 2017 年微信步数情况", width=1100)
heatmap.add("", data, is_calendar_heatmap=True,
            visual_text_color='#000', visual_range_text=['', ''],
            visual_range=[1000, 25000], calendar_cell_size=['auto', 15],
            is_visualmap=True, calendar_date_range="2017",
            visual_orient="horizontal", visual_pos="center",
            visual_top="90%", is_piecewise=True,is_more_utils=True)
heatmap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="8c27a0b015fa4f56a88bed2bef5a0b25" style="width:1100px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_8c27a0b015fa4f56a88bed2bef5a0b25 = echarts.init(document.getElementById('8c27a0b015fa4f56a88bed2bef5a0b25'), 'light', {renderer: 'canvas'});
#
# var option_8c27a0b015fa4f56a88bed2bef5a0b25 = {
#     "title": [
#         {
#             "text": "\u65e5\u5386\u70ed\u529b\u56fe\u793a\u4f8b",
#             "subtext": "\u67d0\u4eba 2017 \u5e74\u5fae\u4fe1\u6b65\u6570\u60c5\u51b5",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
# ...

# %%
path = ""
ppd_list = 'data//lanZhouAir.txt'
df_lcis = pd.read_csv((path+ppd_list))

df_lcis.info()
df_lcis.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1681 entries, 0 to 1680
# Data columns (total 11 columns):
# 城市       1681 non-null object
# 日期       1681 non-null object
# 质量等级     1681 non-null object
# AQI      1681 non-null int64
# AQI排名    1681 non-null int64
# PM2.5    1681 non-null int64
# PM10     1681 non-null int64
# So2      1681 non-null int64
# No2      1681 non-null int64
# Co       1681 non-null int64
# O3       1681 non-null int64
# dtypes: int64(8), object(3)
# memory usage: 144.5+ KB
# Index(['城市', '日期', '质量等级', 'AQI', 'AQI排名', 'PM2.5', 'PM10', 'So2', 'No2', 'Co',
#        'O3'],
#       dtype='object')

# %%
df_lcis
# Out:
#       城市          日期  质量等级  AQI  AQI排名  PM2.5  PM10  So2  No2  Co   O3
# 0     兰州  2013-10-28     良   94     30     61   136   29   29   1   14
# 1     兰州  2013-10-29     良   86     41     61   115   27   29   1   18
# 2     兰州  2013-10-30     良   77     38     56    74   24   30   1   26
# 3     兰州  2013-10-31     良   74     41     51    93   19   42   1   24
# 4     兰州   2013-11-1     良   99     56     73   123   20   47   1   24
# 5     兰州   2013-11-2  轻度污染  113     62     84   156   29   44   1   13
# 6     兰州   2013-11-3  轻度污染  139     83    107   183   36   53   2   26
# 7     兰州   2013-11-4  轻度污染  111     70     78   117   34   54   1   44
# 8     兰州   2013-11-5  轻度污染  135     93     99   196   37   84   2   54
# 9     兰州   2013-11-6  轻度污染  115     57     64   163   31   54   1   49
# 10    兰州   2013-11-7  轻度污染  119     71     79   205   44   55   1   25
# 11    兰州   2013-11-8  轻度污染  123     70     72   168   38   40   1   33
# ...

# %%
data =df_lcis[['日期','AQI']]

# %%
datalist = data.values.tolist()

# %% [markdown]
#     import numpy as np
#     datalist = np.array(data).tolist()

# %%
from pyecharts import HeatMap
year="2014"
heatmap2 = HeatMap("日历热力图", "兰州 "+year+" 年AQI展示", width=1100)
heatmap2.add("", datalist, is_calendar_heatmap=True,
            visual_text_color='#000', visual_range_text=['', ''],
            visual_range=[0, 500], calendar_cell_size=['auto', 15],
            is_visualmap=True, calendar_date_range=year,
            visual_orient="horizontal", visual_pos="left",
            visual_top="80%", is_piecewise=False)
heatmap2
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3c29dd3bb6e646f2b7d55dd762591952" style="width:1100px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3c29dd3bb6e646f2b7d55dd762591952 = echarts.init(document.getElementById('3c29dd3bb6e646f2b7d55dd762591952'), 'light', {renderer: 'canvas'});
#
# var option_3c29dd3bb6e646f2b7d55dd762591952 = {
#     "title": [
#         {
#             "text": "\u65e5\u5386\u70ed\u529b\u56fe",
#             "subtext": "\u5170\u5dde 2014 \u5e74AQI\u5c55\u793a",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
# ...

# %%
AllDateCsv =  pd.read_csv('data//AllCityOneDay.txt')
ban = set(['临沧','中卫' ])
print(AllDateCsv.head())
AllDateCsv = AllDateCsv.drop(['日期'], axis = 1)
# AllDateCsv = AllDateCsv.loc[(AllDateCsv['城市']!='中卫') &( AllDateCsv['城市']!= '临沧')]
# 该死的Echarts，地图了没有数据不会忽略吗？ 报Error居然！！！
#      44         return coordinate
# ValueError: No coordinate is specified for 丽江

Alldate = AllDateCsv.values.tolist()#双层list -> [tuple…… ]
AlldateTuple = []
for listItem in Alldate:
#     if(listItem[0]!= '中卫' && 临沧):
        AlldateTuple.append(tuple(listItem))
print(AlldateTuple)
# Out:
#     城市          日期  AQI
# 0  七台河  2017-12-28   55
# 1   三亚  2017-12-28   37
# 2   三明  2017-12-28   76
# 3  三门峡  2017-12-28  276
# 4   上饶  2017-12-28   91
# ...

# %%
AlldateTuple  = [('七台河', 55), ('三亚', 37), ('三明', 76), ('三门峡', 276), ('上饶', 91), ('东莞', 130), ('东营', 156), ('中山', 117), ('临夏', 236), ('临安', 112), ('临汾', 267), ('临沂', 87), ('丹东', 49), ('丽水', 93),  ('义乌', 84), ('乌海', 137), ('乌鲁木齐', 49), ('乐山', 164), ('九江', 141), ('乳山', 72), ('云浮', 116),('亳州', 171), ('伊春', 39),  ('佛山', 137), ('佳木斯', 35), ('保定', 167), ('保山', 42), ('信阳', 196),  ('克拉玛依', 33), ('六安', 115), ('六盘水', 107), ('兰州', 273), ('兴安盟', 83), ('内江', 174),  ('包头', 178), ('北海', 130), ('十堰', 187), ('南京', 93), ('南充', 132), ('南宁', 102), ('南平', 64), ('南昌', 101), ('南通', 38), ('南阳', 262),  ('即墨', 72), ('厦门', 58), ('双鸭山', 39), ('句容', 117), ('台州', 91), ('合肥', 128), ('吉安', 148), ('吉林', 109), ('吐鲁番', 115), ('吕梁', 181), ('吴忠', 331), ('吴江', 48), ('周口', 213), ('呼伦贝尔', 67), ('呼和浩特', 157), ('和田', 455), ('咸宁', 94), ('咸阳', 369), ('哈密', 80), ('哈尔滨', 158), ('唐山', 191), ('商丘', 117), ('商洛', 134), ('喀什', 120), ('嘉兴', 52), ('嘉峪关', 288), ('四平', 127),  ('塔城', 33),  ('大同', 177), ('大庆', 69), ('大理', 39), ('大连', 58), ('天水', 122), ('太仓', 43), ('太原', 212), ('威海', 56), ('娄底', 130), ('孝感', 130), ('宁德', 78), ('宁波', 64), ('安庆', 196), ('安康', 152), ('安阳', 243), ('安顺', 72), ('定西', 221), ('宜兴', 86), ('宜宾', 214), ('宜昌', 240), ('宜春', 136), ('�
邢台', 200), ('邯郸', 226), ('邵阳', 201), ('郑州', 271), ('郴州', 135), ('鄂尔多斯', 99), ('鄂州', 147), ('酒泉', 289), ('金华', 102), ('金坛', 77), ('金昌', 286), ('钦州', 89), ('铁岭', 118), ('铜仁', 102), ('铜川', 214), ('铜陵', 133), ('银川', 100), ('锦州', 119), ('镇江', 107), ('长春', 108), ('长沙', 118), ('长治', 170), ('阜新', 113), ('阜阳', 179), ('防城港', 67), ('阳江', 165), ('阳泉', 187), ('阿克苏', 221), ('阿勒泰', 31),  ('阿拉善盟', 85), ('陇南', 121), ('随州', 144), ('雅安', 214), ('青岛', 56), ('鞍山', 118), ('韶关', 131), ('马鞍山', 113), ('驻马店', 248), ('鸡西', 31), ('鹤壁', 192), ('鹤岗', 38), ('鹰潭', 118), ('黄冈', 154), ('黄山', 74), ('黄石', 137), ('黑河', 35),  ('齐齐哈尔', 89), ('龙岩', 64)]

# %%
from pyecharts import Geo

geo = Geo("2017-12-28 全国主要城市空气质量", "data from AQI", title_color="#fff",
          title_pos="center", width=1200,
          height=600, background_color='#404a59')
attr, value = geo.cast(AlldateTuple)
# print(Alldate)

geo.add("", attr, value, visual_range=[0, 500], visual_text_color="#fff", maptype='china',
        symbol_size=15, is_visualmap=True)

geo.render()
# html = geo.render()
# from pyecharts.utils import write_utf8_html_file
# write_utf8_html_file('my_demo_chart.html', html)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-4d2e9e468856> in <module>()
#       8
#       9 geo.add("", attr, value, visual_range=[0, 500], visual_text_color="#fff", maptype='china',
# ---> 10         symbol_size=15, is_visualmap=True)
#      11
#      12 geo.render()
#
# D:\Program\anaconda3\lib\site-packages\pyecharts\charts\geo.py in add(self, *args, **kwargs)
#      45
#      46     def add(self, *args, **kwargs):
# ---> 47         self.__add(*args, **kwargs)
#      48
#      49     def __add(
#
# D:\Program\anaconda3\lib\site-packages\pyecharts\charts\geo.py in __add(self, name, attr, value, type, maptype, symbol_size, border_color, geo_normal_color, geo_emphasis_color, geo_cities_coords, is_roam, **kwargs)
#     101         _data = []
#     102         for _name, _value in zip(attr, value):
# ...

# %% [markdown]
# # 我了个去
# 1. 一个page里显示多个图表的Demo

# %%
from pyecharts import Page, Line, Bar

page = Page()
# ... Add data to line
# page.add_chart(geo)
# bar = Bar('Demo kline')
# ... Add data to bar


for i in range(2013, 2019):
#     print(i)
    year=str(i)
    heatmap2 = HeatMap("日历热力图", "兰州 "+year+" 年AQI展示", width=1100)
    heatmap2.add("", datalist, is_calendar_heatmap=True,
                visual_text_color='#000', visual_range_text=['', ''],
                visual_range=[0, 500], calendar_cell_size=['auto', 15],
                is_visualmap=True, calendar_date_range=year,
                visual_orient="horizontal", visual_pos="center",
                visual_top="80%", is_piecewise=True)
    page.add_chart(heatmap2)
page.render()

# %% [markdown]
# demo geo

# %%
data = [
    ("海门", 9),("鄂尔多斯", 12),("招远", 12),("舟山", 12),("齐齐哈尔", 14),("盐城", 15),
    ("赤峰", 16),("青岛", 18),("乳山", 18),("金昌", 19),("泉州", 21),("莱西", 21),
    ("日照", 21),("胶南", 22),("南通", 23),("拉萨", 24),("云浮", 24),("梅州", 25),
    ("文登", 25),("上海", 25),("攀枝花", 25),("威海", 25),("承德", 25),("厦门", 26),
    ("汕尾", 26),("潮州", 26),("丹东", 27),("太仓", 27),("曲靖", 27),("烟台", 28),
    ("福州", 29),("瓦房店", 30),("即墨", 30),("抚顺", 31),("玉溪", 31),("张家口", 31),
    ("阳泉", 31),("莱州", 32),("湖州", 32),("汕头", 32),("昆山", 33),("宁波", 33),
    ("湛江", 33),("揭阳", 34),("荣成", 34),("连云港", 35),("葫芦岛", 35),("常熟", 36),
    ("东莞", 36),("河源", 36),("淮安", 36),("泰州", 36),("南宁", 37),("营口", 37),
    ("惠州", 37),("江阴", 37),("蓬莱", 37),("韶关", 38),("嘉峪关", 38),("广州", 38),
    ("延安", 38),("太原", 39),("清远", 39),("中山", 39),("昆明", 39),("寿光", 40),
    ("盘锦", 40),("长治", 41),("深圳", 41),("珠海", 42),("宿迁", 43),("咸阳", 43),
    ("铜川", 44),("平度", 44),("佛山", 44),("海口", 44),("江门", 45),("章丘", 45),
    ("肇庆", 46),("大连", 47),("临汾", 47),("吴江", 47),("石嘴山", 49),("沈阳", 50),
    ("苏州", 50),("茂名", 50),("嘉兴", 51),("长春", 51),("胶州", 52),("银川", 52),
    ("张家港", 52),("三门峡", 53),("锦州", 54),("南昌", 54),("柳州", 54),("三亚", 54),
    ("自贡", 56),("吉林", 56),("阳江", 57),("泸州", 57),("西宁", 57),("宜宾", 58),
    ("呼和浩特", 58),("成都", 58),("大同", 58),("镇江", 59),("桂林", 59),("张家界", 59),
    ("宜兴", 59),("北海", 60),("金坛", 62),("东营", 62),("牡丹江", 63),
    ("遵义", 63),("绍兴", 63),("扬州", 64),("常州", 64),("潍坊", 65),("重庆", 66),
    ("台州", 67),("南京", 67),("滨州", 70),("贵阳", 71),("无锡", 71),("本溪", 71),
    ("克拉玛依", 72),("渭南", 72),("马鞍山", 72),("宝鸡", 72),("焦作", 75),("句容", 75),
    ("北京", 79),("徐州", 79),("衡水", 80),("包头", 80),("绵阳", 80),("乌鲁木齐", 84),
    ("枣庄", 84),("杭州", 84),("淄博", 85),("鞍山", 86),("溧阳", 86),("库尔勒", 86),
    ("安阳", 90),("开封", 90),("济南", 92),("德阳", 93),("温州", 95),("九江", 96),
    ("邯郸", 98),("临安", 99),("兰州", 99),("沧州", 100),("临沂", 103),("南充", 104),
    ("天津", 105),("富阳", 106),("泰安", 112),("诸暨", 112),("郑州", 113),("哈尔滨", 114),
    ("聊城", 116),("芜湖", 117),("唐山", 119),("平顶山", 119),("邢台", 119),("德州", 120),
    ("济宁", 120),("荆州", 127),("宜昌", 130),("义乌", 132),("丽水", 133),("洛阳", 134),
    ("秦皇岛", 136),("株洲", 143),("石家庄", 147),("莱芜", 148),("常德", 152),("保定", 153),
    ("湘潭", 154),("金华", 157),("岳阳", 169),("长沙", 175),("衢州", 177),("廊坊", 193),
    ("菏泽", 194),("合肥", 229),("武汉", 273)]

geo = Geo("全国主要城市空气质量", "data from pm2.5", title_color="#fff",
          title_pos="center", width=1200,
          height=600, background_color='#404a59')
attr, value = geo.cast(data)
geo.add("", attr, value, visual_range=[0, 200], visual_text_color="#fff", maptype='china|city',
        symbol_size=15, is_visualmap=True)
geo
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="68e18fbaccf8405fb291c12483562954" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china|city'], function(echarts) {
#
# var myChart_68e18fbaccf8405fb291c12483562954 = echarts.init(document.getElementById('68e18fbaccf8405fb291c12483562954'), 'light', {renderer: 'canvas'});
#
# var option_68e18fbaccf8405fb291c12483562954 = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u4e3b\u8981\u57ce\u5e02\u7a7a\u6c14\u8d28\u91cf",
#             "subtext": "data from pm2.5",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
# ...
